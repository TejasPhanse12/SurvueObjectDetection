# %%
from ultralytics import YOLO

# %%
# CPU Interference Time for best yolo11m.pt
model = YOLO('runs/detect/train3/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 524.9±164.8 MB/s, size: 439.2 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 255.0Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11s.pt
model = YOLO('runs/detect/train4/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11s summary (fused): 100 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.0 ms, read: 437.5±115.8 MB/s, size: 412.1 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 241.6Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt
model = YOLO('runs/detect/train5/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 835.6±156.4 MB/s, size: 395.3 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 177.0Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (imgsz=1280)
model = YOLO('runs/detect/train6/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.2 ms, read: 1006.1±122.0 MB/s, size: 384.8 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 157.4Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (imgsz=1280)
model = YOLO('runs/detect/yolo8notraffic/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.8±0.5 ms, read: 1081.2±184.7 MB/s, size: 404.0 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 233.1Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (imgsz=1280)
model = YOLO('runs/detect/train7/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 937.6±248.6 MB/s, size: 399.5 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 259.4Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (imgsz=1280 and No- Traffic Signs)
model = YOLO('runs/detect/train8/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 865.6±383.2 MB/s, size: 393.5 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 162.1Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_copy/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (train imgsz=1280)
model = YOLO('runs/detect/train6/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1080, device='cpu')
# Out:
# WARNING ⚠️ imgsz=[1080] must be multiple of max stride 32, updating to [1088]
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.2±0.2 ms, read: 886.4±148.4 MB/s, size: 371.4 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 260.5Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# ...

# %%
# CPU Interference Time for best yolo11n.pt (imgsz=960)
model = YOLO('runs/detect/train5/weights/best.pt')

results = model.val(data='data.yaml', imgsz=1280, device='cpu')
# Out:
# Ultralytics 8.3.233 🚀 Python-3.10.16 torch-2.5.1 CPU (Intel Xeon CPU E5-2680 v4 @ 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 420.1±118.8 MB/s, size: 437.5 KB)
# val: Scanning /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 248.5Kit/s 0.0s
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00055.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00325.jpg: 1 duplicate labels removed
# val: /courses/CS5330.202610/students/phanse.t/FinalProject/dataset_og/val/images/ti_lindau_V105_2015sept_100_VIRB_VIRB0031_0m_10m_I00415.jpg: 1 duplicate labels removed
# ...
