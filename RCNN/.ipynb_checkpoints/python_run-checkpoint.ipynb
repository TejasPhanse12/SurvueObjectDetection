# %%
# !python annotations.py
# Out:
# Loading annotations from: /courses/CS5330.202610/students/patel.harshil3/FinalProject/instances.json
# Found 500 images
# Found 9787 annotations
# Found 3 categories
#
# Categories:
#   1: human
#   2: trafficsign
#   3: vehicle
# Saved (1/10): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I07710.jpg
# Saved (2/10): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I06811.jpg
# Saved (3/10): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I04923.jpg
# Saved (4/10): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I00637.jpg
# Saved (5/10): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I00217.jpg
# ...

# %%
# !python dataset.py
# Out:
# Loading annotations...
# Total images: 500
# Total annotations: 9787
# Categories: ['human', 'trafficsign', 'vehicle']
#
# Train images: 400
# Validation images: 100
#
# Train annotations: 7621
# Validation annotations: 2166
#
# Saved: dataset/train_annotations.json
# Saved: dataset/val_annotations.json
#
# Copying images to train folder...
# Copied 399/400 images
# Missing 1 images: ['ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I03304.jpg']...
# Copying images to validation folder...
# Copied 100/100 images
#
# ...
# Dataset preparation complete!
# ...
#
# Dataset structure:
#   dataset/
#     ├── train/  (399 images)
#     ├── val/  (100 images)
#     ├── train_annotations.json
#     └── val_annotations.json
#
# Ready for model training!

# %%
# !python annotations.py
# Out:
# Loading annotations from: /courses/CS5330.202610/students/patel.harshil3/FinalProject/instances.json
# Found 500 images
# Found 9787 annotations
# Found 3 categories
#
# Categories:
#   1: human
#   2: trafficsign
#   3: vehicle
# Saved (1/500): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I07710.jpg
# Saved (2/500): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I06811.jpg
# Saved (3/500): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I04923.jpg
# Saved (4/500): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I00637.jpg
# Saved (5/500): /courses/CS5330.202610/students/patel.harshil3/FinalProject/results/ti_lindau_V106_2015sept_100_VIRB_VIRB0031_10m_10m_I00217.jpg
# ...

# %%
# !python train_model.py
# Out:
# Using device: cuda
# ...
# FASTER R-CNN TRAINING
# ...
#
# Loading datasets...
# Train dataset: 400 images
# Val dataset: 100 images
#
# Creating model...
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Starting training...
#
# Epoch 1/50: 100%|███████████████████| 50/50 [00:50<00:00,  1.00s/it, loss=0.947]
# Epoch 1 - Average Loss: 1.3357
# ...

# %%
# !python model_evaluation.py
# Out:
# Using device: cuda
#
# ...
# MODEL EVALUATION - VALIDATION SET WITH mAP
# ...
# Loading model...
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ...
